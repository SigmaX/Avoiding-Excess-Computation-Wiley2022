# %% [markdown]
# # Analysis of results of the Q-learner using Gremlin and SWEET
#
# The other notebook is focused on the Gremlin results, whereas this is focused on how
# well the Q-learner performed.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook
from datetime import datetime as dt

from scipy.stats import wilcoxon, levene

sns.set_theme() # default Seaborn theme

from analytics import consolidate_csv_as_df, consolidate_learner_csv_as_df

# %% [markdown]
# # Load the data
# First load, organize, and clean up the data for both the SWEET and UNSWEETENED runs.

# %% [markdown]
# ## Un-SWEETENED data

# %%
q_learner_unsweetened_runs = consolidate_learner_csv_as_df(Path('nonsweet_output').glob('*progress.csv'), infer_run=True)
# Out:
# reading nonsweet_output/run6_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run8_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run6_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run4_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run0_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 5
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run2_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 5
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 5
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 5
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run3_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 5
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 5
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run0_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 5
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run3_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 5
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 9
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 5
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 12
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run4_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run3_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run5_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 2
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 15
# New dataframe length 2000
# reading nonsweet_output/run9_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 3
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 7
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 0
# New dataframe length 5000
# reading nonsweet_output/run0_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 16
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 11
# New dataframe length 2000
# reading nonsweet_output/run1_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run7_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 8
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 14
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 13
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run8_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 10
# New dataframe length 2000
# reading nonsweet_output/run6_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 6
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 1
# New dataframe length 2000
# reading nonsweet_output/run0_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 17
# New dataframe length 2000
# reading nonsweet_output/run2_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 4
# New dataframe length 2000
# reading nonsweet_output/run5_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 5
# New dataframe length 2000

# %%
q_learner_unsweetened_runs
# Out:
#       Episode  Reward  TrainTime  Position  Velocity     Angle  \
# 0           0   230.0   0.017528 -0.048255 -0.031692 -0.011041
# 1           1   179.0   0.013066  0.015853  0.026159  0.009649
# 2           2   209.0   0.015771  0.015853  0.026159  0.009649
# 3           3   206.0   0.015397  0.015853  0.026159  0.009649
# 4           4    47.0   0.003608  0.015853  0.026159  0.009649
# ...       ...     ...        ...       ...       ...       ...
# 1995     1995    57.0   0.002754  0.047366 -0.023219 -0.014872
# 1996     1996    44.0   0.002160  0.047366 -0.023219 -0.014872
# 1997     1997    45.0   0.002194  0.047366 -0.023219 -0.014872
# 1998     1998    45.0   0.002161  0.047366 -0.023219 -0.014872
# 1999     1999    48.0   0.002289  0.047366 -0.023219 -0.014872
#
#       RotationalVelocity  run  iteration
# 0              -0.030790    6         17
# 1              -0.040193    6         17
# 2              -0.040193    6         17
# 3              -0.040193    6         17
# 4              -0.040193    6         17
# ...                  ...  ...        ...
# 1995            0.018819    5          5
# 1996            0.018819    5          5
# 1997            0.018819    5          5
# 1998            0.018819    5          5
# 1999            0.018819    5          5
#
# [390000 rows x 9 columns]

# %%
q_learner_unsweetened_runs['type'] = 'notsweet'

# %% [markdown]
# We can see the episodes reset between iterations.

# %%
q_learner_unsweetened_runs.groupby(['run','iteration']).Episode.agg(['min','max'])
# Out:
#                min   max
# run iteration
# 0   0            0  4999
#     1            0  1999
#     2            0  1999
#     3            0  1999
#     4            0  1999
# ...            ...   ...
# 9   13           0  1999
#     14           0  1999
#     15           0  1999
#     16           0  1999
#     17           0  1999
#
# [180 rows x 2 columns]

# %% [markdown]
# As you can see, iteration 0 has 5k episodes, and the rest 2k.  And the episode numbers reset with each new iteration.  We need to serialize the episode numbering by run.

# %%
def normalize_episode(row):
    """ add new episode that continues range for entire run """
    if row.iteration == 0:
        return row.Episode
    else:
        return (row.iteration - 1) * 2000 + 5000 + row.Episode

# %%
q_learner_unsweetened_runs['corrected_episode'] = q_learner_unsweetened_runs.apply(normalize_episode, axis=1)

# %%
q_learner_unsweetened_runs.groupby(['run','iteration']).corrected_episode.agg(['min','max'])
# Out:
#                  min    max
# run iteration
# 0   0              0   4999
#     1           5000   6999
#     2           7000   8999
#     3           9000  10999
#     4          11000  12999
# ...              ...    ...
# 9   13         29000  30999
#     14         31000  32999
#     15         33000  34999
#     16         35000  36999
#     17         37000  38999
#
# [180 rows x 2 columns]

# %% [markdown]
# ## SWEETened data

# %%
q_learner_sweetened_runs = consolidate_learner_csv_as_df(Path('sweet_output').glob('*progress.csv'), infer_run=True)
# Out:
# reading sweet_output/run6_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run8_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run6_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run4_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run0_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 5
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run2_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 5
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 5
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 5
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run3_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 5
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 5
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run0_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 5
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run3_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 5
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter9_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 9
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 5
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter12_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 12
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run4_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 4
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run3_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 3
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run5_gremlin-enhanced-iter2_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 2
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter15_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 15
# New dataframe length 2000
# reading sweet_output/run9_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 9
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter3_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 3
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter7_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 7
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter0_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 0
# New dataframe length 5000
# reading sweet_output/run0_gremlin-enhanced-iter16_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 16
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter11_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 11
# New dataframe length 2000
# reading sweet_output/run1_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 1
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run7_gremlin-enhanced-iter8_q_learner_progress.csv
# Adding run number 7
# Adding iteration number 8
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter14_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 14
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter13_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 13
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run8_gremlin-enhanced-iter10_q_learner_progress.csv
# Adding run number 8
# Adding iteration number 10
# New dataframe length 2000
# reading sweet_output/run6_gremlin-enhanced-iter6_q_learner_progress.csv
# Adding run number 6
# Adding iteration number 6
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter1_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 1
# New dataframe length 2000
# reading sweet_output/run0_gremlin-enhanced-iter17_q_learner_progress.csv
# Adding run number 0
# Adding iteration number 17
# New dataframe length 2000
# reading sweet_output/run2_gremlin-enhanced-iter4_q_learner_progress.csv
# Adding run number 2
# Adding iteration number 4
# New dataframe length 2000
# reading sweet_output/run5_gremlin-enhanced-iter5_q_learner_progress.csv
# Adding run number 5
# Adding iteration number 5
# New dataframe length 2000

# %%
q_learner_sweetened_runs['type'] = 'sweet'

# %%
q_learner_sweetened_runs['corrected_episode'] = q_learner_sweetened_runs.apply(normalize_episode, axis=1)

# %%
q_learner_sweetened_runs.groupby(['run','iteration']).corrected_episode.agg(['min','max'])
# Out:
#                  min    max
# run iteration
# 0   0              0   4999
#     1           5000   6999
#     2           7000   8999
#     3           9000  10999
#     4          11000  12999
# ...              ...    ...
# 9   13         29000  30999
#     14         31000  32999
#     15         33000  34999
#     16         35000  36999
#     17         37000  38999
#
# [180 rows x 2 columns]

# %% [markdown]
# ## Merge data
#
# Merge the two dataframes.

# %%
q_learner_runs = pd.concat([q_learner_sweetened_runs, q_learner_unsweetened_runs])

# %%
# We just want a subset
q_learner_runs_subset = q_learner_runs[q_learner_runs.corrected_episode % 100 == 0].copy()

# %% [markdown]
# # Compute best-so-far for all the runs by run type

# %%
q_learner_runs_subset.sort_values(by=['type','run','corrected_episode'], inplace=True)

# %%
q_learner_runs_subset.reset_index(drop=False, inplace=True) # because all the indices will be messed up due to concat

# %%
q_learner_runs_subset = q_learner_runs_subset[['type','run','corrected_episode','Reward']].copy()

# %%
q_learner_runs_subset['best_so_far'] = q_learner_runs_subset.groupby(['type','run']).Reward.cummax()

# %%
q_learner_runs_subset
# Out:
#           type  run  corrected_episode  Reward  best_so_far
# 0     notsweet    0                  0    35.0         35.0
# 1     notsweet    0                100    20.0         35.0
# 2     notsweet    0                200    20.0         35.0
# 3     notsweet    0                300    22.0         35.0
# 4     notsweet    0                400    20.0         35.0
# ...        ...  ...                ...     ...          ...
# 7795     sweet    9              38500    58.0        178.0
# 7796     sweet    9              38600    64.0        178.0
# 7797     sweet    9              38700   111.0        178.0
# 7798     sweet    9              38800    76.0        178.0
# 7799     sweet    9              38900    71.0        178.0
#
# [7800 rows x 5 columns]

# %%
q_learner_runs_subset.corrected_episode.max()
# Out:
# 38900

# %%
not_sweet_best = q_learner_runs_subset.query("corrected_episode == 38900 and type == 'notsweet'").best_so_far

# %%
sweet_best = q_learner_runs_subset.query("corrected_episode == 38900 and type == 'sweet'").best_so_far

# %%
wilcoxon(not_sweet_best, sweet_best, alternative='greater')
# Out:
# /root/miniconda3/envs/leap/lib/python3.8/site-packages/scipy/stats/_morestats.py:3145: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /root/miniconda3/envs/leap/lib/python3.8/site-packages/scipy/stats/_morestats.py:3159: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# WilcoxonResult(statistic=8.0, pvalue=0.13666083914614907)

# %%
levene(not_sweet_best, sweet_best)
# Out:
# LeveneResult(statistic=1.82331991491905, pvalue=0.19365341670603076)

# %% [markdown]
# # Visualizations
#
# Now we get to look at the data.  We're interested in comparing the bestp-so-far
# curves of the two sets of experiments.  We may also be interested in generating
# a boxplot showing the relative time the best solution was found first.

# %%
q_learner_impact_plot = sns.lineplot(data=q_learner_runs_subset,
                        x='corrected_episode', y='best_so_far',
                        hue='type', ci=95,
                        ).set(title='Impact of SWEET on Q-Learner training performance',
                             xlabel='Episode', ylabel='Mean of best-so-far fitnesses')
# Out:
# <div id='ba2e6612-dbee-41c3-8849-3d4d4b9cdf92'></div>

# %%
plt.legend(title='Run type', labels=['Basic Async','SWEET'])
# Out:
# <div id='572c1e47-0656-42ce-845d-65bc4a4fbc17'></div>

# %%
plt.savefig('gremlin_cart_pole_bsf.png')
# Out:
# <div id='fc34ce10-40a1-42fd-9d04-d6ae04ce25de'></div>

# %%
plt.savefig('gremlin_cart_pole_bsf.pdf')
# Out:
# <div id='33d9a629-f66b-4402-aa47-1eb288586b85'></div>

# %%
plt.clf()
# Out:
# <div id='e5b33878-4db6-4006-a48e-070c1efbda12'></div>

# %% [markdown]
# We want to compare the final scores. Use box plots to denote the distribution between the two.

# %%
final_box_plot = sns.boxplot(data=q_learner_runs_subset[q_learner_runs_subset.corrected_episode == 38900],
                             y='best_so_far', x='type').set(title='Comparison of final Q-learner scores', ylabel='final scores')
# Out:
# <div id='7dff3ecc-ee21-4ae7-85d9-0d7bfdfaf956'></div>

# %%
plt.xticks(plt.xticks()[0], ['Basic Async', 'SWEET'])
# Out:
# <div id='dc6c1ff7-e858-487f-8f42-b135b2ef686b'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /root/EA_work/async_2021/mark_results/gremlin/cart-pole/learner_analysis.ipynb Cell 41' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/root/EA_work/async_2021/mark_results/gremlin/cart-pole/learner_analysis.ipynb#ch0000040vscode-remote?line=0'>1</a> plt.xticks(plt.xticks()[0], ['Basic Async', 'SWEET'])
#
# File ~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/pyplot.py:1795, in xticks(ticks, labels, **kwargs)
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/pyplot.py?line=1792'>1793</a>         l.update(kwargs)
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/pyplot.py?line=1793'>1794</a> else:
# -> <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/pyplot.py?line=1794'>1795</a>     labels = ax.set_xticklabels(labels, **kwargs)
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/pyplot.py?line=1796'>1797</a> return locs, labels
#
# File ~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axes/_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axes/_base.py?line=73'>74</a> def wrapper(self, *args, **kwargs):
# ---> <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axes/_base.py?line=74'>75</a>     return get_method(self)(*args, **kwargs)
#
# File ~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1795'>1796</a> if fontdict is not None:
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1796'>1797</a>     kwargs.update(fontdict)
# -> <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1797'>1798</a> return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py:1720, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1715'>1716</a> if isinstance(locator, mticker.FixedLocator):
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1716'>1717</a>     # Passing [] as a list of ticklabels is often used as a way to
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1717'>1718</a>     # remove all tick labels, so only error for > 0 ticklabels
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1718'>1719</a>     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1719'>1720</a>         raise ValueError(
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1720'>1721</a>             "The number of FixedLocator locations"
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1721'>1722</a>             f" ({len(locator.locs)}), usually from a call to"
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1722'>1723</a>             " set_ticks, does not match"
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1723'>1724</a>             f" the number of ticklabels ({len(ticklabels)}).")
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1724'>1725</a>     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    <a href='file:///~/miniconda3/envs/leap/lib/python3.8/site-packages/matplotlib/axis.py?line=1725'>1726</a>     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (6), usually from a call to set_ticks, does not match the number of ticklabels (2).

# %%
plt.savefig('gremlin_cart_pole_final_score_boxplot.png')
# Out:
# <div id='cfa69d5a-bd33-474c-859c-7587dd797c62'></div>

# %%
plt.savefig('gremlin_cart_pole_final_score_boxplot.pdf')
# Out:
# <div id='9a019f1b-44f9-4f3f-b3bc-e589004ad9ea'></div>

# %%
df = q_learner_runs.copy()
df = df[['type','run','corrected_episode','Reward','TrainTime']]
#df = df[df.corrected_episode % 100 == 0].copy()
df.sort_values(by=['type','run','corrected_episode'], inplace=True)

df['best_so_far'] = df.groupby(['type','run']).Reward.cummax()
df['CumulTime'] = df.groupby(['type','run']).apply(lambda g: g.TrainTime.cumsum().reset_index()).iloc[:,1].values
df['CumulTime'] = df['CumulTime'] * 1000
df['CumulTime'] = df.CumulTime.apply(lambda t: dt.fromtimestamp(t))
df = df.groupby(['type','run']).apply(lambda g: g.set_index('CumulTime').resample('S').ffill().reset_index())
df['CumulTime'] = df['CumulTime'] - df['CumulTime'].min()
df['CumulTime'] = df['CumulTime'].apply(lambda t: t.seconds)
df = df[df.CumulTime % 100 == 0].copy().drop(['type','run'],axis=1).reset_index()
df['CumulTime'] = df.CumulTime / 1000

# %%
G = sns.lineplot(data=df[df.CumulTime > 0.2], x='CumulTime', y = 'best_so_far', hue='type', ci=95)
#G.axes.set_xticklabels([l.get_text()  if idx % 100 ==0 else '' for idx, l in enumerate(G.axes.get_xticklabels())])
G.legend().set_title('')
plt.xlabel('Time (s)')
plt.ylabel('Best Fitness So Far')
plt.savefig('gremlin_cart_pole_time_curve.pdf')
plt.savefig('gremlin_cart_pole_time_curve.png')
plt.close()
# Out:
# <div id='c6c60a8c-46e1-434a-8230-2bdc2cf0f91a'></div>
